# %%
text = "mango apple banana"
print(text.split())
# Out:
# ['mango', 'apple', 'banana']

# %%
text ="mango, banana,apple,kiwi"
print(text.split(","))

# %%
text = "mango,apple,banana"
print(text.split(",",2))
